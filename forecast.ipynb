# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import solcast as s
s.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, save='solcast.json',debug=1)
f = s.Solcast()
print(f)
f.plot_daily()
# Out:
# Solcast credentials provided
# Using data from solcast.json
#
# Solcast yield for 13 days (E = estimated, F = forecasts):
#
#     2023-05-20 Sat E: 38.11 kwh
#     2023-05-21 Sun E: 37.83 kwh
#     2023-05-22 Mon E: 31.33 kwh
#     2023-05-23 Tue E: 28.79 kwh
#     2023-05-24 Wed E: 39.13 kwh
#     2023-05-25 Thu E: 36.97 kwh
# --> 2023-05-26 Fri F: 40.23 kwh <--
#     2023-05-27 Sat F: 39.31 kwh
#     2023-05-28 Sun F: 26.98 kwh
#     2023-05-29 Mon F: 40.67 kwh
#     2023-05-30 Tue F: 38.58 kwh
#     2023-05-31 Wed F: 33.28 kwh
#     2023-06-01 Thu F: 40.10 kwh
