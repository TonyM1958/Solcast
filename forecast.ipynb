# %% [markdown]
# <h3>Solar Forecast</h3>
#
# Get 13 day solar forecast from your Solcast account / resource ids.

# %%
# run forecast
import private as my
import solcast as s
s.solcast_setting(api_key=my.solcast_api_key, rids=my.rids, debug=1)
f = s.Solcast()
print(f)
f.plot_daily()
# Out:
# Solcast credentials provided
# Using data for 2023-05-27 from solcast.json
# Solcast yield for 13 days (E = estimated, F = forecasts):
#
#     2023-05-21 Sun E: 37.83 kwh
#     2023-05-22 Mon E: 31.33 kwh
#     2023-05-23 Tue E: 28.79 kwh
#     2023-05-24 Wed E: 39.13 kwh
#     2023-05-25 Thu E: 36.63 kwh
#     2023-05-26 Fri E: 40.68 kwh
# --> 2023-05-27 Sat F: 38.19 kwh <--
#     2023-05-28 Sun F: 30.46 kwh
#     2023-05-29 Mon F: 40.66 kwh
#     2023-05-30 Tue F: 38.24 kwh
#     2023-05-31 Wed F: 35.89 kwh
#     2023-06-01 Thu F: 39.90 kwh
#     2023-06-02 Fri F: 34.41 kwh
